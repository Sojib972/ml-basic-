# %%
import pandas as pd

# %%
df = pd.read_excel("supershops.xlsx")

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.tail()
# Out:
#     Marketing Spend  Administration  Transport     Area    Profit
# 45          1000.23       124153.04    1903.93    Dhaka  64926.08
# 46          1315.46       115816.21  297114.46  Rangpur  49490.75
# 47             0.00       135426.92       0.00      Ctg  42559.73
# 48           542.05        51743.15       0.00    Dhaka  35673.41
# 49             0.00       116983.80   45173.06      Ctg  14681.40

# %%
df.head(3)
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39

# %%
df["Marketing Spend"]
# Out:
# 0     114523.61
# 1     162597.70
# 2     153441.51
# 3     144372.41
# 4     142107.34
# 5     131876.90
# 6     134615.46
# 7     130298.13
# 8     120542.52
# 9     123334.88
# 10    101913.08
# 11    100671.96
# 12     93863.75
# 13     91992.39
# 14    119943.24
# 15    165349.20
# 16     78013.11
# 17     94657.16
# 18     91749.16
# 19     86419.70
# 20     76253.86
# 21     78389.47
# 22     73994.56
# 23     67532.53
# 24     77044.01
# 25     64664.71
# 26     75328.87
# 27     72107.60
# 28     66051.52
# 29     65605.48
# 30     61994.48
# 31     61136.38
# 32     63408.86
# 33     55493.95
# 34     46426.07
# 35     46014.02
# 36     28663.76
# 37     44069.95
# 38     20229.59
# 39     38558.51
# 40     28754.33
# 41     27892.92
# 42     23640.93
# 43     15505.73
# 44     22177.74
# 45      1000.23
# 46      1315.46
# 47         0.00
# 48       542.05
# 49         0.00
# Name: Marketing Spend, dtype: float64

# %%
df[["Marketing Spend"]]
# Out:
#     Marketing Spend
# 0         114523.61
# 1         162597.70
# 2         153441.51
# 3         144372.41
# 4         142107.34
# 5         131876.90
# 6         134615.46
# 7         130298.13
# 8         120542.52
# 9         123334.88
# 10        101913.08
# 11        100671.96
# 12         93863.75
# 13         91992.39
# 14        119943.24
# 15        165349.20
# 16         78013.11
# 17         94657.16
# 18         91749.16
# 19         86419.70
# 20         76253.86
# 21         78389.47
# 22         73994.56
# 23         67532.53
# 24         77044.01
# 25         64664.71
# 26         75328.87
# 27         72107.60
# 28         66051.52
# 29         65605.48
# 30         61994.48
# 31         61136.38
# 32         63408.86
# 33         55493.95
# 34         46426.07
# 35         46014.02
# 36         28663.76
# 37         44069.95
# 38         20229.59
# 39         38558.51
# 40         28754.33
# 41         27892.92
# 42         23640.93
# 43         15505.73
# ...

# %%
df.columns
# Out:
# Index(['Marketing Spend', 'Administration', 'Transport', 'Area', 'Profit'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Marketing Spend  50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Transport        49 non-null     float64
#  3   Area             50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
df[["Marketing Spend","Area"]][5:10]
# Out:
#    Marketing Spend     Area
# 5        131876.90    Dhaka
# 6        134615.46      Ctg
# 7        130298.13  Rangpur
# 8        120542.52    Dhaka
# 9        123334.88      Ctg

# %%
type(df[["Area"]])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["Marketing Spend"])
# Out:
# pandas.core.series.Series

# %%
df.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
len(df)
# Out:
# 50

# %%
df["Marketing Spend"].max()
# Out:
# 165349.2

# %%
df["Marketing Spend"].min()
# Out:
# 0.0

# %%
df["Marketing Spend"].mean()
# Out:
# 73721.6156

# %%
df["Marketing Spend"].std()
# Out:
# 45902.25648230753

# %%
df["Administration"].quantile(.25)
# Out:
# 103730.875

# %%
df["Administration"].quantile(.50)
# Out:
# 122699.795

# %%
df["Marketing Spend"].sort_values(ascending= False)
# Out:
# 15    165349.20
# 1     162597.70
# 2     153441.51
# 3     144372.41
# 4     142107.34
# 6     134615.46
# 5     131876.90
# 7     130298.13
# 9     123334.88
# 8     120542.52
# 14    119943.24
# 0     114523.61
# 10    101913.08
# 11    100671.96
# 17     94657.16
# 12     93863.75
# 13     91992.39
# 18     91749.16
# 19     86419.70
# 21     78389.47
# 16     78013.11
# 24     77044.01
# 20     76253.86
# 26     75328.87
# 22     73994.56
# 27     72107.60
# 23     67532.53
# 28     66051.52
# 29     65605.48
# 25     64664.71
# 32     63408.86
# 30     61994.48
# 31     61136.38
# 33     55493.95
# 34     46426.07
# 35     46014.02
# 37     44069.95
# 39     38558.51
# 40     28754.33
# 36     28663.76
# 41     27892.92
# 42     23640.93
# 44     22177.74
# 38     20229.59
# 43     15505.73
# 46      1315.46
# 45      1000.23
# 48       542.05
# 47         0.00
# 49         0.00
# Name: Marketing Spend, dtype: float64

# %%
df.sort_values(by=['Marketing Spend'],  ascending=False, na_position='first').nlargest(5,"Marketing Spend")
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 15        165349.20       122616.84  261776.23    Dhaka  129917.04
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df["Marketing Spend"].sort_values(ascending= False).nlargest(5)
# Out:
# 15    165349.20
# 1     162597.70
# 2     153441.51
# 3     144372.41
# 4     142107.34
# Name: Marketing Spend, dtype: float64

# %%
df.nsmallest(5, "Profit")
# Out:
#     Marketing Spend  Administration  Transport     Area    Profit
# 49             0.00       116983.80   45173.06      Ctg  14681.40
# 48           542.05        51743.15       0.00    Dhaka  35673.41
# 47             0.00       135426.92       0.00      Ctg  42559.73
# 46          1315.46       115816.21  297114.46  Rangpur  49490.75
# 45          1000.23       124153.04    1903.93    Dhaka  64926.08

# %%
df["Profit"] > 60000
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46    False
# 47    False
# 48    False
# 49    False
# Name: Profit, dtype: bool

# %%
df[df["Profit"] > 100000]
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 6         134615.46       147198.87  127716.82      Ctg  156122.51
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 9         123334.88       108679.17  304981.62      Ctg  149759.96
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 11        100671.96        91790.61  249744.55      Ctg  144259.40
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# ...

# %%
df[df["Profit"] == 101004.64]
# Out:
#     Marketing Spend  Administration  Transport   Area     Profit
# 29         65605.48       153032.06  107138.38  Dhaka  101004.64

# %%
df[(df["Area"] == "Dhaka") | (df["Area"] == "Rangpur")]
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# 14        119943.24       156547.42  256512.92  Rangpur  132602.65
# 15        165349.20       122616.84  261776.23    Dhaka  129917.04
# 17         94657.16       145077.58  282574.31    Dhaka  125370.37
# 18         91749.16       114175.79  294919.57  Rangpur  124266.90
# ...

# %%
df[(df["Area"] == "Dhaka") & (df["Area"] == "Rangpur")]
# Out:
# Empty DataFrame
# Columns: [Marketing Spend, Administration, Transport, Area, Profit]
# Index: []

# %%
df[df["Area"].isin(["Rangpur"])]
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# 14        119943.24       156547.42  256512.92  Rangpur  132602.65
# 18         91749.16       114175.79  294919.57  Rangpur  124266.90
# 22         73994.56       122782.75  303319.26  Rangpur  110352.25
# 23         67532.53       105751.03  304768.73  Rangpur  108733.99
# 26         75328.87       144135.98  134050.07  Rangpur  105733.54
# 28         66051.52       182645.56  118148.20  Rangpur  103282.38
# 30         61994.48       115641.28   91131.24  Rangpur   99937.59
# 33         55493.95       103057.49  214634.81  Rangpur   96778.92
# ...

# %%
df[df["Profit"]== df["Profit"].min()]
# Out:
#     Marketing Spend  Administration  Transport Area   Profit
# 49              0.0        116983.8   45173.06  Ctg  14681.4

# %%
df["Profit"].max()
# Out:
# 192261.83

# %%
df[df["Profit"]== df["Profit"].max()]
# Out:
#    Marketing Spend  Administration  Transport   Area     Profit
# 0        114523.61        136897.8   471784.1  Dhaka  192261.83

# %%
# loc and iloc
df.loc[0]
# Out:
# Marketing Spend    114523.61
# Administration      136897.8
# Transport           471784.1
# Area                   Dhaka
# Profit             192261.83
# Name: 0, dtype: object

# %%
df.head(1)
# Out:
#    Marketing Spend  Administration  Transport   Area     Profit
# 0        114523.61        136897.8   471784.1  Dhaka  192261.83

# %%
df.iloc[0]
# Out:
# Marketing Spend    114523.61
# Administration      136897.8
# Transport           471784.1
# Area                   Dhaka
# Profit             192261.83
# Name: 0, dtype: object

# %%
df.iloc[0:4]
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99

# %%
df.loc[0:4]
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.set_index("Area").head()
# Out:
#          Marketing Spend  Administration  Transport     Profit
# Area
# Dhaka          114523.61       136897.80  471784.10  192261.83
# Ctg            162597.70       151377.59  443898.53  191792.06
# Rangpur        153441.51       101145.55  407934.54  191050.39
# Dhaka          144372.41       118671.85  383199.62  182901.99
# Rangpur        142107.34        91391.77  366168.42  166187.94

# %%
df1 = df.copy()
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
del df1["Area"]

# %%
df1.head(2)
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0        114523.61       136897.80  471784.10  192261.83
# 1        162597.70       151377.59  443898.53  191792.06

# %%
df.head(2)
# Out:
#    Marketing Spend  Administration  Transport   Area     Profit
# 0        114523.61       136897.80  471784.10  Dhaka  192261.83
# 1        162597.70       151377.59  443898.53    Ctg  191792.06

# %%
df1.drop("Profit", axis= 1)
# Out:
#     Marketing Spend  Administration  Transport
# 0         114523.61       136897.80  471784.10
# 1         162597.70       151377.59  443898.53
# 2         153441.51       101145.55  407934.54
# 3         144372.41       118671.85  383199.62
# 4         142107.34        91391.77  366168.42
# 5         131876.90        99814.71  362861.36
# 6         134615.46       147198.87  127716.82
# 7         130298.13       145530.06  323876.68
# 8         120542.52       148718.95  311613.29
# 9         123334.88       108679.17  304981.62
# 10        101913.08       110594.11  229160.95
# 11        100671.96        91790.61  249744.55
# 12         93863.75       127320.38  249839.44
# 13         91992.39       135495.07  252664.93
# 14        119943.24       156547.42  256512.92
# 15        165349.20       122616.84  261776.23
# 16         78013.11       121597.55  264346.06
# 17         94657.16       145077.58  282574.31
# 18         91749.16       114175.79  294919.57
# ...

# %%
df1.head(2)
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0        114523.61       136897.80  471784.10  192261.83
# 1        162597.70       151377.59  443898.53  191792.06

# %%
df1 = df1.drop("Profit", axis= 1)

# %%
df1.head(2)
# Out:
#    Marketing Spend  Administration  Transport
# 0        114523.61       136897.80  471784.10
# 1        162597.70       151377.59  443898.53

# %%
df1.drop("Transport", axis= 1, inplace= True)

# %%
df1.head(2)
# Out:
#    Marketing Spend  Administration
# 0        114523.61       136897.80
# 1        162597.70       151377.59

# %%
df.head(2)
# Out:
#    Marketing Spend  Administration  Transport   Area     Profit
# 0        114523.61       136897.80  471784.10  Dhaka  192261.83
# 1        162597.70       151377.59  443898.53    Ctg  191792.06

# %%
x = df.drop("Profit", axis=1)

# %%
x.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
y = df[["Profit"]]

# %%
y.head()
# Out:
#       Profit
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.rename(columns= {"Area": "area"}, inplace= True)

# %%
df.head(2)
# Out:
#    Marketing Spend  Administration  Transport   area     Profit
# 0        114523.61       136897.80  471784.10  Dhaka  192261.83
# 1        162597.70       151377.59  443898.53    Ctg  191792.06

# %%
dic = {
    "name":["sajib","rajib","tuhin"],
    "age": [25,12,41]
}

df = pd.DataFrame(dic)

# %%
df
# Out:
#     name  age
# 0  sajib   25
# 1  rajib   12
# 2  tuhin   41

# %%
dic1 = {
    "name":["rajib","simon","safawat"],
    "age": [20,25,14]
}

df1 = pd.DataFrame(dic1)

# %%
df1
# Out:
#       name  age
# 0    rajib   20
# 1    simon   25
# 2  safawat   14

# %%
df
# Out:
#     name  age
# 0  sajib   25
# 1  rajib   12
# 2  tuhin   41

# %%
new = pd.concat([df1,df])
new
# Out:
#       name  age
# 0    rajib   20
# 1    simon   25
# 2  safawat   14
# 0    sajib   25
# 1    rajib   12
# 2    tuhin   41

# %%
new1 = pd.concat([df1,df], axis= 1)
new1
# Out:
#       name  age   name  age
# 0    rajib   20  sajib   25
# 1    simon   25  rajib   12
# 2  safawat   14  tuhin   41

# %%
#!pip install pandas

# %%
import pandas as pd 
df = pd.read_excel("supershops.xlsx")

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.shape
# Out:
# (50, 5)

# %%
df.isna().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
#NaN handling 
import numpy as np
data = np.random.rand(8,3)

for i in range(data.shape[1]):
    nan_val = np.random.choice(6,3 , replace= False) #generate 4 unique random integer value ranging 0-5 .indices of the rows that will be set to NaN
    data[nan_val, i]= np.nan

    
df = pd.DataFrame(data, columns=["col1","col2","col3"])

# %%
df
# Out:
#        col1      col2      col3
# 0  0.539653  0.871085       NaN
# 1       NaN       NaN  0.145423
# 2  0.066336  0.796009       NaN
# 3  0.263980  0.092005  0.555445
# 4       NaN       NaN  0.026001
# 5       NaN       NaN       NaN
# 6  0.385419  0.346787  0.581635
# 7  0.171541  0.042959  0.550750

# %%
data = np.random.rand(8,3)
data
# Out:
# array([[0.29078213, 0.25929381, 0.95968954],
#        [0.90629424, 0.4331013 , 0.01113864],
#        [0.46726464, 0.09788432, 0.07900587],
#        [0.67050829, 0.626673  , 0.55869101],
#        [0.32761751, 0.8698633 , 0.85290144],
#        [0.12339701, 0.48990053, 0.01083255],
#        [0.18173782, 0.80448726, 0.25022528],
#        [0.86099338, 0.55186233, 0.12926541]])

# %%
for i in range(data.shape[1]):
    print(i)
# Out:
# 0
# 1
# 2

# %%
nan_val = np.random.choice(6,3 , replace= False)
nan_val
# Out:
# array([3, 5, 2])

# %%
data[nan_val, i]= np.nan
data
# Out:
# array([[0.29078213, 0.25929381, 0.95968954],
#        [0.90629424, 0.4331013 , 0.01113864],
#        [0.46726464, 0.09788432,        nan],
#        [0.67050829, 0.626673  ,        nan],
#        [0.32761751, 0.8698633 , 0.85290144],
#        [0.12339701, 0.48990053,        nan],
#        [0.18173782, 0.80448726, 0.25022528],
#        [0.86099338, 0.55186233, 0.12926541]])

# %%
#NaN handling 
import numpy as np
data = np.random.rand(8,3)

for i in range(data.shape[1]):
    nan_val = np.random.choice(6,3 , replace= False) #generate 4 unique random integer value ranging 0-5 .indices of the rows that will be set to NaN
    data[nan_val, i]= np.nan

    
df = pd.DataFrame(data, columns=["col1","col2","col3"])
df
# Out:
#        col1      col2      col3
# 0  0.276965  0.585740       NaN
# 1       NaN       NaN       NaN
# 2       NaN       NaN  0.600802
# 3  0.029761  0.106006  0.956274
# 4       NaN  0.082598  0.639550
# 5  0.725451       NaN       NaN
# 6  0.817239  0.381630  0.367980
# 7  0.319285  0.862216  0.099263

# %%
df.isnull().sum()
# Out:
# col1    3
# col2    3
# col3    3
# dtype: int64

# %%
df.isna().sum()
# Out:
# col1    3
# col2    3
# col3    3
# dtype: int64

# %%
df.fillna("hello",inplace= True)
# Out:
# C:\Users\Sajib Saha\AppData\Local\Temp\ipykernel_4068\1926223228.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'hello' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("hello",inplace= True)

# %%
df
# Out:
#        col1      col2      col3
# 0  0.276965  0.585740       NaN
# 1       NaN       NaN       NaN
# 2       NaN       NaN  0.600802
# 3  0.029761  0.106006  0.956274
# 4       NaN  0.082598  0.639550
# 5  0.725451       NaN       NaN
# 6  0.817239  0.381630  0.367980
# 7  0.319285  0.862216  0.099263

# %%
df.fillna({
    "col1" : 1,
    "col2" : 2,
    "col3" : 3
}, inplace= True)
df
# Out:
#        col1      col2      col3
# 0  0.276965  0.585740  3.000000
# 1  1.000000  2.000000  3.000000
# 2  1.000000  2.000000  0.600802
# 3  0.029761  0.106006  0.956274
# 4  1.000000  0.082598  0.639550
# 5  0.725451  2.000000  3.000000
# 6  0.817239  0.381630  0.367980
# 7  0.319285  0.862216  0.099263

# %%
#NaN handling 
import numpy as np
data = np.random.rand(8,3)

for i in range(data.shape[1]):
    nan_val = np.random.choice(6,3 , replace= False) #generate 4 unique random integer value ranging 0-5 .indices of the rows that will be set to NaN
    data[nan_val, i]= np.nan

    
df = pd.DataFrame(data, columns=["col1","col2","col3"])
df
# Out:
#        col1      col2      col3
# 0  0.526733  0.963818       NaN
# 1  0.481958       NaN  0.522047
# 2  0.178435  0.335481  0.604571
# 3       NaN       NaN       NaN
# 4       NaN  0.454970  0.222567
# 5       NaN       NaN       NaN
# 6  0.983768  0.730529  0.651584
# 7  0.013407  0.911027  0.724772

# %%
df.drop("col1", axis= 1)
# Out:
#        col2      col3
# 0  0.975839       NaN
# 1       NaN       NaN
# 2  0.195737  0.295829
# 3  0.208260  0.384044
# 4       NaN       NaN
# 5       NaN  0.559062
# 6  0.326622  0.591689
# 7  0.068446  0.675303

# %%
df.dropna()
