# %%
# !pip install pandas

# %%
import pandas as pd

# %%
data = [2,8,"NaN",7,6]
tf = pd.Series(data)
tf
# Out:
# 0      2
# 1      8
# 2    NaN
# 3      7
# 4      6
# dtype: object

# %%
tf.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5 entries, 0 to 4
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      object
# dtypes: object(1)
# memory usage: 172.0+ bytes

# %%
tf = pd.DataFrame(data)
tf
# Out:
#      0
# 0    2
# 1    8
# 2  NaN
# 3    7
# 4    6

# %%
tf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5 non-null      object
# dtypes: object(1)
# memory usage: 172.0+ bytes

# %%
df= pd.DataFrame(tf, columns = ["seri"])
df
# Out:
#    seri
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
data = [2,8,"NaN",7,6]
df= pd.DataFrame(data, columns = ["num"])
df
# Out:
#    num
# 0    2
# 1    8
# 2  NaN
# 3    7
# 4    6

# %%
# List to DataFrame
new =[["Sajib","rajib","sumon"],[12,25,12],[14,45,89]]
df = pd.DataFrame(new,columns=["cus1","cus2","cus3"])
df
# Out:
#     cus1   cus2   cus3
# 0  Sajib  rajib  sumon
# 1     12     25     12
# 2     14     45     89

# %%
# Dictionary to DataFrame
dic = {
    "name": ["sajib","rajib","jewel"],
    "age": [25,26,24],
    "city": ["Dhaka","sylhet","cumilla"]
}
df = pd.DataFrame(dic)
df
# Out:
#     name  age     city
# 0  sajib   25    Dhaka
# 1  rajib   26   sylhet
# 2  jewel   24  cumilla

# %%
se = {1,5,7,9}
df = pd.DataFrame(se, columns= ["num"])
print(df)
# Out:
#    num
# 0    1
# 1    5
# 2    9
# 3    7

# %%
t = (1,2,5,7,65,True,False)
df = pd.DataFrame(t, columns= ["num"])
df
# Out:
#      num
# 0      1
# 1      2
# 2      5
# 3      7
# 4     65
# 5   True
# 6  False

# %%
df
# Out:
#      num
# 0      1
# 1      2
# 2      5
# 3      7
# 4     65
# 5   True
# 6  False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   num     7 non-null      object
# dtypes: object(1)
# memory usage: 188.0+ bytes

# %%
df.dtypes
# Out:
# num    object
# dtype: object

# %%
df["age"]=df["age"].astype("float16")
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df["age"]=df["age"].astype("float16")
# ...

# %%
df.dtypes
# Out:
# num    object
# dtype: object

# %%
dic = {
    "name": ["sajib","rajib","jewel"],
    "age": [4588825,5565526,8755524],
    "city": ["Dhaka","sylhet","cumilla"]
}
df = pd.DataFrame(dic)
df
# Out:
#     name      age     city
# 0  sajib  4588825    Dhaka
# 1  rajib  5565526   sylhet
# 2  jewel  8755524  cumilla

# %%
df["age"]=df["age"].astype("int16")
df
# Out:
#     name    age     city
# 0  sajib   1305    Dhaka
# 1  rajib  -5034   sylhet
# 2  jewel -26300  cumilla

# %%
#READ FILE 
import pandas as pd

# %%
df = pd.read_csv("BostonHousing.csv")

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.tail()
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           b  lstat  medv
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
df.head(30)
# Out:
#        crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 0   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2   0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5   0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7   0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10  0.22489  12.5   7.87     0  0.524    NaN   94.3  6.3467    5  311
# 11  0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# ...
